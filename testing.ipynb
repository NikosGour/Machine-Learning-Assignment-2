# %%
from MLProject2Dataset import MLProject2Dataset

# %%
dataset = MLProject2Dataset(data_dir='data', metadata_fname='metadata.csv')

# %%
dataset.df['dx'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>
